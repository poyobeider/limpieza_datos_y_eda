# %% [markdown]
# # Limpieza de datos
#
# La mayoría de la gente piensa que ser científico de datos significa estar corriendo modelos avanzados de Machine Learning todo el tiempo. La realidad es muy distinta:
#
# ![Tiempo de un científico de datos](https://github.com/poyobeider/limpieza_datos_y_eda/blob/main/img/datascientist_time.jpeg?raw=1)
#
# La gran mayoría del tiempo se va **limpiando y organizando** los datos con los que queremos trabajar.
#
# Los científicos de datos utilizamos herramientas como Pandas, Numpy, Matplotlib y Seaborn para limpiar los datos con los que queremos hacer algo.
#
# ## ETL
#
# Un tipo de tarea que realizamos con gran frecuencia los científicos de datos son los **ETL**.
#
# ![Proceso de ETL](https://github.com/poyobeider/limpieza_datos_y_eda/blob/main/img/etl.png?raw=1)
#
# ETL es un acrónimo que significa Extract, Transform, Load. Es un proceso que se utiliza para extraer datos de una fuente, transformarlos en un formato que sea adecuado para el análisis y cargarlos en una base de datos o algún otro sistema de almacenamiento.
#
# ## Ejemplo práctico
#
# Los datos que usaremos para esta limpieza y nuestro siguiente análisis son datos de incidencia delictiva en nuestro país.
#
# La iniciativa de datos abiertos del gobierno de México nos proporciona datos de incidencia delictiva desde 2015 hasta la fecha. Los datos se actualizan todos los meses y se pueden descargar desde el siguiente enlace: https://www.gob.mx/sesnsp/acciones-y-programas/datos-abiertos-de-incidencia-delictiva
#
# ---
#
# Como podemos ver en el portal, se proporcionan los datos tanto a nivel estatal como a nivel municipal. En este caso, utilizaremos los datos a nivel estatal.
#
# Descarguemos los datos y guardemos el archivo CSV en la carpeta data con el nombre `datos_delitos.csv`.
#
# ---
#
# Ahora leamos el archivo CSV y veamos cómo se ven los datos.
#
# Primero que nada, importemos pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/datos_delitos.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-2618966558.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('sample_data/datos_delitos.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 1: invalid continuation byte

# %% [markdown]
# Aquí tenemos un error muy común que suele ocurrir cuando un archivo se guarda en una computadora con cierto "encoding".
#
# Un encoding es una tabla que relaciona un número con un carácter. Por ejemplo, en la tabla ASCII, el número 65 corresponde a la letra "A".
#
# Si el archivo que estamos leyendo fue guardado con un encoding distinto al que pandas espera, nos arrojará un error.
#
# Para solucionar esto, podemos utilizar el parámetro `encoding` de la función `pd.read_csv()` y especificar el encoding correcto.
#
# ¿Pero cómo sabemos con qué encoding cuenta el archivo?
#
# La realidad es que la gran mayoría de los archivos los encontrarán en encoding utf-8 y Pandas no va a dar ningún error. Aquí estamos teniendo este problema porque la computadora que utilizan para generar este archivo uso un encoding diferente a utf-8.
#
# En México, por lo general, si un archivo no está en utf-8, lo más seguro es que esté en `ISO-8859-1` o `latin1`.

# %% [markdown]
# Intentemos cargar el archivo especificando el encoding `ISO-8859-1`.

# %%
df = pd.read_csv('sample_data/datos_delitos.csv', encoding='ISO-8859-1')
df.head()
# Out:
#     Año  Clave_Ent         Entidad            Bien jurídico afectado  \
# 0  2015          1  Aguascalientes  La vida y la Integridad corporal
# 1  2015          1  Aguascalientes  La vida y la Integridad corporal
# 2  2015          1  Aguascalientes  La vida y la Integridad corporal
# 3  2015          1  Aguascalientes  La vida y la Integridad corporal
# 4  2015          1  Aguascalientes  La vida y la Integridad corporal
#
#   Tipo de delito  Subtipo de delito          Modalidad  Enero  Febrero  Marzo  \
# 0      Homicidio   Homicidio doloso  Con arma de fuego      3        0      2
# 1      Homicidio   Homicidio doloso    Con arma blanca      1        1      0
# 2      Homicidio   Homicidio doloso  Con otro elemento      0        0      2
# 3      Homicidio   Homicidio doloso    No especificado      2        0      0
# 4      Homicidio  Homicidio culposo  Con arma de fuego      0        0      0
#
#    Abril  Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  \
# 0      1     1      1      2       1           2        2        2.0
# 1      0     0      1      0       1           0        0        0.0
# 2      2     3      2      0       1           2        0        0.0
# 3      1     0      0      0       0           0        0        0.0
# 4      0     1      0      0       0           0        0        0.0
#
#    Diciembre
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        0.0

# %% [markdown]
# Y vemos que ya podemos leer correctamente el archivo.
#
#
# ¿Existe alguna forma de verificar el encoding de un archivo sin tener que estar adivinando?
#
# ChatGTP generó el siguiente código:

# %%
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        rawdata = f.read()
    result = chardet.detect(rawdata)
    return result

file_path = 'sample_data/datos_delitos.csv'
encoding_info = detect_encoding(file_path)
print(f"Detected encoding: {encoding_info['encoding']}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1621394227.py in <cell line: 0>()
#       8
#       9 file_path = 'sample_data/datos_delitos.csv'
# ---> 10 encoding_info = detect_encoding(file_path)
#      11 print(f"Detected encoding: {encoding_info['encoding']}")
#
# /tmp/ipython-input-1621394227.py in detect_encoding(file_path)
#       4     with open(file_path, 'rb') as f:
#       5         rawdata = f.read()
# ----> 6     result = chardet.detect(rawdata)
#       7     return result
#       8
#
# /usr/local/lib/python3.12/dist-packages/chardet/__init__.py in detect(byte_str, should_rename_legacy)
#      47         byte_str = bytearray(byte_str)
#      48     detector = UniversalDetector(should_rename_legacy=should_rename_legacy)
# ---> 49     detector.feed(byte_str)
#      50     return detector.close()
#      51
#
# /usr/local/lib/python3.12/dist-packages/chardet/universaldetector.py in feed(self, byte_str)
#     272                 self._charset_probers.append(MacRomanProber())
#     273             for prober in self._charset_probers:
# --> 274                 if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     275                     self.result = {
#     276                         "encoding": prober.charset_name,
#
# /usr/local/lib/python3.12/dist-packages/chardet/latin1prober.py in feed(self, byte_str)
#     119
#     120     def feed(self, byte_str: Union[bytes, bytearray]) -> ProbingState:
# --> 121         byte_str = self.remove_xml_tags(byte_str)
#     122         for c in byte_str:
#     123             char_class = Latin1_CharToClass[c]
#
# /usr/local/lib/python3.12/dist-packages/chardet/charsetprober.py in remove_xml_tags(buf)
#     130                 in_tag = False
#     131             # https://github.com/python/typeshed/issues/8182
# --> 132             elif buf_char == b"<":  # type: ignore[comparison-overlap]
#     133                 if curr > prev and not in_tag:
#     134                     # Keep everything after last non-extended-ASCII,
#
# KeyboardInterrupt:

# %% [markdown]
# Sigamos...

# %%
df.tail(3)
# Out:
#         Año  Clave_Ent    Entidad  \
# 34493  2025         32  Zacatecas
# 34494  2025         32  Zacatecas
# 34495  2025         32  Zacatecas
#
#                                   Bien jurídico afectado  \
# 34493  Otros bienes jurídicos afectados (del fuero co...
# 34494  Otros bienes jurídicos afectados (del fuero co...
# 34495  Otros bienes jurídicos afectados (del fuero co...
#
#                                   Tipo de delito  \
# 34493  Delitos cometidos por servidores públicos
# 34494                                Electorales
# 34495              Otros delitos del Fuero Común
#
#                                Subtipo de delito  \
# 34493  Delitos cometidos por servidores públicos
# 34494                                Electorales
# 34495              Otros delitos del Fuero Común
#
#                                        Modalidad  Enero  Febrero  Marzo  \
# 34493  Delitos cometidos por servidores públicos     37       35     24
# 34494                                Electorales      8        3      1
# 34495              Otros delitos del Fuero Común    190      164    184
#
#        Abril  Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  \
# 34493     40    30     32     34      25          20       31        NaN
# 34494      0     2      2      0       0           1        0        NaN
# 34495    172    98    103    107     113         133      100        NaN
#
#        Diciembre
# 34493        NaN
# 34494        NaN
# 34495        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34496 entries, 0 to 34495
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     34496 non-null  int64
#  1   Clave_Ent               34496 non-null  int64
#  2   Entidad                 34496 non-null  object
#  3   Bien jurídico afectado  34496 non-null  object
#  4   Tipo de delito          34496 non-null  object
#  5   Subtipo de delito       34496 non-null  object
#  6   Modalidad               34496 non-null  object
#  7   Enero                   34496 non-null  int64
#  8   Febrero                 34496 non-null  int64
#  9   Marzo                   34496 non-null  int64
#  10  Abril                   34496 non-null  int64
#  11  Mayo                    34496 non-null  int64
#  12  Junio                   34496 non-null  int64
#  13  Julio                   34496 non-null  int64
#  14  Agosto                  34496 non-null  int64
#  15  Septiembre              34496 non-null  int64
#  16  Octubre                 34496 non-null  int64
#  17  Noviembre               31360 non-null  float64
#  18  Diciembre               31360 non-null  float64
# dtypes: float64(2), int64(12), object(5)
# memory usage: 5.0+ MB

# %% [markdown]
# Bien. Están muy bien los datos. Sin embargo, tenemos un problema con el que es muy común encontrarnos.
#
# Resulta que el formato en el que está el archivo es fácil entender por seres humanos:
#
#
# ```markdown
# | Año      | Entidad  | Enero    | Febrero  | Mes X    |
# |----------|----------|----------|----------|----------|
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# ```
#
# Vemos que tenemos los meses como encabezados. Es decir, el archivo está tratando cada mes como si fuera una variable.
#
# Nosotros como científicos de datos estamos más interesados en conjuntos de datos que no estén en este formato de "resumen" o "tabla dinámica". Para nosotros, lo ideal sería que cada mes fuera simplemente una observación más en nuestro conjunto de datos. Es decir, queremos transformar la tabla de arriba en:
#
# ```markdown
# | Año      | Entidad  | Mes        |
# |----------|----------|------------|
# |   ...    |   ...    |   Enero    |
# |   ...    |   ...    |   Febrero  |
# |   ...    |   ...    |   Marzo    |
# |   ...    |   ...    |   Abril    |
# |   ...    |   ...    |   Mes X    |
# ```
#
# A este tipo de formato le llamos "formato largo de datos".

# %% [markdown]
# Haremos las siguientes limpiezas:
# * Transformar los nombres de las columnas para que no tengan caracteres especiales y estén siempre en minúsculas
# * Convertir el dataset a un formato de datos "largo"

# %%
for col in df.columns:
    print(col)
# Out:
# Año
# Clave_Ent
# Entidad
# Bien jurídico afectado
# Tipo de delito
# Subtipo de delito
# Modalidad
# Enero
# Febrero
# Marzo
# Abril
# Mayo
# Junio
# Julio
# Agosto
# Septiembre
# Octubre
# Noviembre
# Diciembre

# %%
len(df.columns)
# Out:
# 19

# %% [markdown]
# ### Limpiar nombres de columnas

# %%
def limpiar_columnas(df):
    columnas_limpias = []
    for col in df.columns:
        # convertir a minusculas, reemplazar espacios por guiones bajos y eliminar caracteres especiales
        col = col.lower().replace(" ", "_").replace("ñ", "ni").replace(".", "").replace("á", "a").replace("é", "e").replace("í","i").replace("ó", "o").replace("ú", "u")
        columnas_limpias.append(col)

    df.columns = columnas_limpias

    return df

# %%
df.head(2)
# Out:
#     Año  Clave_Ent         Entidad            Bien jurídico afectado  \
# 0  2015          1  Aguascalientes  La vida y la Integridad corporal
# 1  2015          1  Aguascalientes  La vida y la Integridad corporal
#
#   Tipo de delito Subtipo de delito          Modalidad  Enero  Febrero  Marzo  \
# 0      Homicidio  Homicidio doloso  Con arma de fuego      3        0      2
# 1      Homicidio  Homicidio doloso    Con arma blanca      1        1      0
#
#    Abril  Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  \
# 0      1     1      1      2       1           2        2        2.0
# 1      0     0      1      0       1           0        0        0.0
#
#    Diciembre
# 0        1.0
# 1        1.0

# %%
df = limpiar_columnas(df)

# %%
df.head(3)
# Out:
#    anio  clave_ent         entidad            bien_juridico_afectado  \
# 0  2015          1  Aguascalientes  La vida y la Integridad corporal
# 1  2015          1  Aguascalientes  La vida y la Integridad corporal
# 2  2015          1  Aguascalientes  La vida y la Integridad corporal
#
#   tipo_de_delito subtipo_de_delito          modalidad  enero  febrero  marzo  \
# 0      Homicidio  Homicidio doloso  Con arma de fuego      3        0      2
# 1      Homicidio  Homicidio doloso    Con arma blanca      1        1      0
# 2      Homicidio  Homicidio doloso  Con otro elemento      0        0      2
#
#    abril  mayo  junio  julio  agosto  septiembre  octubre  noviembre  \
# 0      1     1      1      2       1           2        2        2.0
# 1      0     0      1      0       1           0        0        0.0
# 2      2     3      2      0       1           2        0        0.0
#
#    diciembre
# 0        1.0
# 1        1.0
# 2        0.0

# %% [markdown]
# Muy bien. Ahora lo que queremos hacer es quitar algunas columnas. Nos interesan nada más las siguientes:

# %%
df[['anio', 'entidad']]
# Out:
#        anio         entidad
# 0      2015  Aguascalientes
# 1      2015  Aguascalientes
# 2      2015  Aguascalientes
# 3      2015  Aguascalientes
# 4      2015  Aguascalientes
# ...     ...             ...
# 34491  2025       Zacatecas
# 34492  2025       Zacatecas
# 34493  2025       Zacatecas
# 34494  2025       Zacatecas
# 34495  2025       Zacatecas
#
# [34496 rows x 2 columns]

# %%
df = df[['anio', 'clave_ent', 'entidad', 'tipo_de_delito', 'subtipo_de_delito', 'modalidad','enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre']]
df.head(2)
# Out:
#    anio  clave_ent         entidad tipo_de_delito subtipo_de_delito  \
# 0  2015          1  Aguascalientes      Homicidio  Homicidio doloso
# 1  2015          1  Aguascalientes      Homicidio  Homicidio doloso
#
#            modalidad  enero  febrero  marzo  abril  mayo  junio  julio  \
# 0  Con arma de fuego      3        0      2      1     1      1      2
# 1    Con arma blanca      1        1      0      0     0      1      0
#
#    agosto  septiembre  octubre  noviembre  diciembre
# 0       1           2        2        2.0        1.0
# 1       1           0        0        0.0        1.0

# %% [markdown]
# ### Formato largo de datos

# %% [markdown]
# Ahora, usaremos el método `melt` para convertir las columnas a observaciones.
#
# Queremos convervar las coumnas:
# * anio
# * clave_ent
# * entidad
# * tipo_de_delito
# * subtipo_de_delito
# * modalidad
#
# El resto de las columnas las vamos a juntar en una nueva columna llamada "nombre_mes" y sus valores los vamos a sumar en otra llamada "frecuencia"

# %%
print("Shape ", df.shape)
# Out:
# Shape  (34496, 18)

# %%
datos_long = df.melt(id_vars=['anio', 'clave_ent', 'entidad','tipo_de_delito', 'subtipo_de_delito', 'modalidad'], var_name='nombre_mes', value_name='frecuencia')

# %%
print("Shape: ", datos_long.shape)
# Out:
# Shape:  (413952, 8)

# %%
datos_long.head(5)
# Out:
#    anio  clave_ent         entidad tipo_de_delito  subtipo_de_delito  \
# 0  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 1  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 2  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 3  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 4  2015          1  Aguascalientes      Homicidio  Homicidio culposo
#
#            modalidad nombre_mes  frecuencia
# 0  Con arma de fuego      enero         3.0
# 1    Con arma blanca      enero         1.0
# 2  Con otro elemento      enero         0.0
# 3    No especificado      enero         2.0
# 4  Con arma de fuego      enero         0.0

# %%
datos_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413952 entries, 0 to 413951
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   anio               413952 non-null  int64
#  1   clave_ent          413952 non-null  int64
#  2   entidad            413952 non-null  object
#  3   tipo_de_delito     413952 non-null  object
#  4   subtipo_de_delito  413952 non-null  object
#  5   modalidad          413952 non-null  object
#  6   nombre_mes         413952 non-null  object
#  7   frecuencia         407680 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 25.3+ MB

# %% [markdown]
# Supongamos que para este análisis, no nos importan los niveles subtipo de delito y modalidad. O sea, no queremos tener la distinción entre homicidios dolosos y culposos (sé que son bastante diferentes, pero simplifiquemos nuestro ejemplo).
#
# Vamos a agrupar nuestro dataframe por anio, clave_ent, entidad, tipo_de_delito y nombre_mes. Esto hará que todos los tipos de homicidios se sumen al tipo "homicidio" o todos los tipos de robo de vehículo (con o sin violencia) se sumen a "robo de vehículo".

# %%
datos_long = datos_long.groupby(['anio', 'clave_ent', 'entidad', 'tipo_de_delito', 'nombre_mes'])['frecuencia'].sum().reset_index()

# %%
datos_long[datos_long.tipo_de_delito == 'Robo'].sample(15)
# Out:
#         anio  clave_ent                          entidad tipo_de_delito  \
# 21988   2016         14                          Jalisco           Robo
# 147746  2024         20                           Oaxaca           Robo
# 32548   2017          4                         Campeche           Robo
# 20073   2016         10                          Durango           Robo
# 91108   2020         30  Veracruz de Ignacio de la Llave           Robo
# 71424   2019         21                           Puebla           Robo
# 82470   2020         12                         Guerrero           Robo
# 97833   2021         12                         Guerrero           Robo
# 11915   2015         25                          Sinaloa           Robo
# 149673  2024         24                  San Luis Potosí           Robo
# 22944   2016         16              Michoacán de Ocampo           Robo
# 122313  2022         31                          Yucatán           Robo
# 33030   2017          5             Coahuila de Zaragoza           Robo
# 31593   2017          2                  Baja California           Robo
# 167904  2025         30  Veracruz de Ignacio de la Llave           Robo
#
#         nombre_mes  frecuencia
# 21988      febrero      2249.0
# 147746   diciembre       485.0
# 32548      febrero        78.0
# 20073    noviembre       895.0
# 91108      febrero      2185.0
# 71424        abril      3354.0
# 82470        junio       374.0
# 97833    noviembre       549.0
# 11915   septiembre       771.0
# 149673   noviembre      1136.0
# 22944        abril      1131.0
# 122313   noviembre        43.0
# 33030        junio       946.0
# 31593    noviembre      3923.0
# 167904       abril      1278.0

# %% [markdown]
# Mostremos todos los estados y su respectiva clave

# %%
datos_long[['clave_ent', 'entidad']].drop_duplicates().sort_values('entidad')
# Out:
#        clave_ent                          entidad
# 0              1                   Aguascalientes
# 480            2                  Baja California
# 960            3              Baja California Sur
# 1440           4                         Campeche
# 2880           7                          Chiapas
# 3360           8                        Chihuahua
# 3840           9                 Ciudad de México
# 1920           5             Coahuila de Zaragoza
# 2400           6                           Colima
# 4320          10                          Durango
# 4800          11                       Guanajuato
# 5280          12                         Guerrero
# 5760          13                          Hidalgo
# 6240          14                          Jalisco
# 7200          16              Michoacán de Ocampo
# 7680          17                          Morelos
# 6720          15                           México
# 8160          18                          Nayarit
# 8640          19                       Nuevo León
# 9120          20                           Oaxaca
# 9600          21                           Puebla
# 10080         22                        Querétaro
# 10560         23                     Quintana Roo
# 11040         24                  San Luis Potosí
# 11520         25                          Sinaloa
# 12000         26                           Sonora
# 12480         27                          Tabasco
# 12960         28                       Tamaulipas
# 13440         29                         Tlaxcala
# 13920         30  Veracruz de Ignacio de la Llave
# 14400         31                          Yucatán
# 14880         32                        Zacatecas

# %% [markdown]
# Ahora Veamos todos los datos de delitos de una entidad en específico. Por ejemplo, Nuevo león

# %%
datos_long[datos_long['clave_ent'] == 19].sample(15)
# Out:
#         anio  clave_ent     entidad  \
# 131855  2023         19  Nuevo León
# 131768  2023         19  Nuevo León
# 116554  2022         19  Nuevo León
# 101220  2021         19  Nuevo León
# 8805    2015         19  Nuevo León
# 147188  2024         19  Nuevo León
# 101125  2021         19  Nuevo León
# 85892   2020         19  Nuevo León
# 70474   2019         19  Nuevo León
# 147102  2024         19  Nuevo León
# 101102  2021         19  Nuevo León
# 85899   2020         19  Nuevo León
# 8715    2015         19  Nuevo León
# 85669   2020         19  Nuevo León
# 39428   2017         19  Nuevo León
#
#                                            tipo_de_delito  nombre_mes  \
# 131855                      Otros delitos del Fuero Común  septiembre
# 131768                                            Incesto        mayo
# 116554                                               Robo     octubre
# 101220                                 Tráfico de menores       abril
# 8805                                            Extorsión   noviembre
# 147188                    Otros delitos contra la familia        mayo
# 101125                      Otros delitos del Fuero Común      agosto
# 85892                                    Violación simple        mayo
# 70474                                                Robo     octubre
# 147102                                          Homicidio       junio
# 101102                    Otros delitos contra la familia   diciembre
# 85899   Violencia de género en todas sus modalidades d...       enero
# 8715                             Contra el medio ambiente       enero
# 85669                                Hostigamiento sexual      agosto
# 39428                                            Amenazas        mayo
#
#         frecuencia
# 131855       540.0
# 131768         0.0
# 116554      1450.0
# 101220         0.0
# 8805          51.0
# 147188       479.0
# 101125       456.0
# 85892         56.0
# 70474       1323.0
# 147102       206.0
# 101102       494.0
# 85899          0.0
# 8715           0.0
# 85669          4.0
# 39428        491.0

# %%
datos_long[(datos_long['clave_ent'] > 19) &  (datos_long['clave_ent'] < 24) & (datos_long['tipo_de_delito'] == 'Homicidio')].sample(15)
# Out:
#         anio  clave_ent       entidad tipo_de_delito  nombre_mes  frecuencia
# 162943  2025         20        Oaxaca      Homicidio       marzo       193.0
# 86619   2020         21        Puebla      Homicidio       enero       116.0
# 10305   2015         22     Querétaro      Homicidio   noviembre        45.0
# 10300   2015         22     Querétaro      Homicidio     febrero        38.0
# 87581   2020         23  Quintana Roo      Homicidio       julio       129.0
# 25658   2016         22     Querétaro      Homicidio   diciembre        33.0
# 71263   2019         21        Puebla      Homicidio       marzo       178.0
# 117824  2022         22     Querétaro      Homicidio        mayo        44.0
# 163907  2025         22     Querétaro      Homicidio  septiembre        50.0
# 87585   2020         23  Quintana Roo      Homicidio   noviembre       113.0
# 9347    2015         20        Oaxaca      Homicidio  septiembre         0.0
# 56861   2018         23  Quintana Roo      Homicidio       julio       123.0
# 10307   2015         22     Querétaro      Homicidio  septiembre        40.0
# 148540  2024         22     Querétaro      Homicidio     febrero        44.0
# 70785   2019         20        Oaxaca      Homicidio   noviembre       139.0

# %% [markdown]
# ### Valores de fechas
#
# Finalmente, queremos tener una columna "fecha". Actualmente tenemos el año y el nombre del mes, pero no tenemos como tal una columna que tenga un tipo de dato fecha. Eso hace que filtrar por fecha sea complicado.
#
# Por ejemplo, si queremos conocer todos los homicidios de Oaxaca en enero 2024, haríamos lo siguiente:

# %%
datos_long[
    (datos_long['clave_ent'] == 20) &
    (datos_long['tipo_de_delito'] == 'Homicidio') &
    (datos_long['anio'] == 2024) &
    (datos_long['nombre_mes'] == 'enero')
]
# Out:
#         anio  clave_ent entidad tipo_de_delito nombre_mes  frecuencia
# 147579  2024         20  Oaxaca      Homicidio      enero       154.0

# %% [markdown]
# Creemos una columna de fecha.
#
# Primero tenemos que convertir el nombre de mes a un número, en donde 1 es enero, 2 febrero, etc.

# %%
datos_long.sample(2)
# Out:
#         anio  clave_ent    entidad     tipo_de_delito nombre_mes  frecuencia
# 109371  2022          4   Campeche  Trata de personas      enero         0.0
# 141805  2024          8  Chihuahua             Fraude     agosto       438.0

# %%
datos_long["nueva_columna"] = "dato vacío"
datos_long.sample(6)
# Out:
#         anio  clave_ent              entidad         tipo_de_delito  \
# 23546   2016         18              Nayarit           Abuso sexual
# 89220   2020         26               Sonora     Tráfico de menores
# 1338    2015          3  Baja California Sur                  Rapto
# 138762  2024          2      Baja California           Acoso sexual
# 101426  2021         20               Oaxaca      Evasión de presos
# 4886    2015         11           Guanajuato  Corrupción de menores
#
#        nombre_mes  frecuencia nueva_columna
# 23546   diciembre         0.0    dato vacío
# 89220       abril         0.0    dato vacío
# 1338        junio         0.0    dato vacío
# 138762      junio        17.0    dato vacío
# 101426  diciembre         0.0    dato vacío
# 4886    diciembre         9.0    dato vacío

# %%
# Diccionario de ayuda para convertir
meses = {
    "enero": 1,
    "febrero": 2,
    "marzo": 3,
    "abril": 4,
    "mayo": 5,
    "junio": 6,
    "julio": 7,
    "agosto": 8,
    "septiembre": 9,
    "octubre": 10,
    "noviembre": 11,
    "diciembre": 12
}

datos_long['mes'] = datos_long['nombre_mes'].map(meses)
datos_long.sample(5)
# Out:
#         anio  clave_ent  entidad  \
# 94813   2021          6   Colima
# 112062  2022         10  Durango
# 84986   2020         18  Nayarit
# 144777  2024         14  Jalisco
# 147991  2024         21   Puebla
#
#                                            tipo_de_delito nombre_mes  \
# 94813   Incumplimiento de obligaciones de asistencia f...     agosto
# 112062                                          Homicidio      junio
# 84986                                        Abuso sexual  diciembre
# 144777                 Otros delitos contra el patrimonio  noviembre
# 147991                                  Evasión de presos      marzo
#
#         frecuencia nueva_columna  mes
# 94813         59.0    dato vacío    8
# 112062        39.0    dato vacío    6
# 84986          0.0    dato vacío   12
# 144777         0.0    dato vacío   11
# 147991         1.0    dato vacío    3

# %%
datos_long["frecuencia_mas_10"] = datos_long["frecuencia"] + 10
datos_long.sample(5)
# Out:
#         anio  clave_ent         entidad                   tipo_de_delito  \
# 31115   2017          1  Aguascalientes                             Robo
# 23345   2016         17         Morelos  Otros delitos contra la familia
# 61831   2019          1  Aguascalientes                             Robo
# 149938  2024         25         Sinaloa                         Falsedad
# 61460   2019          1  Aguascalientes               Abuso de confianza
#
#         nombre_mes  frecuencia nueva_columna  mes  frecuencia_mas_10
# 31115   septiembre      1492.0    dato vacío    9             1502.0
# 23345        julio        21.0    dato vacío    7               31.0
# 61831        marzo      1085.0    dato vacío    3             1095.0
# 149938     octubre         4.0    dato vacío   10               14.0
# 61460         mayo        64.0    dato vacío    5               74.0

# %%
datos_long["anio_mes"] = datos_long["anio"].astype(str) + datos_long["mes"].astype(str)
datos_long.sample(6)
# Out:
#         anio  clave_ent              entidad            tipo_de_delito  \
# 47216   2018          3  Baja California Sur                  Falsedad
# 88503   2020         25              Sinaloa             Falsificación
# 92856   2021          2      Baja California                 Homicidio
# 122578  2022         32            Zacatecas                  Falsedad
# 7967    2015         17              Morelos              Narcomenudeo
# 127278  2023         10              Durango  Contra el medio ambiente
#
#         nombre_mes  frecuencia nueva_columna  mes  frecuencia_mas_10 anio_mes
# 47216         mayo         6.0    dato vacío    5               16.0    20185
# 88503        enero        17.0    dato vacío    1               27.0    20201
# 92856        abril       291.0    dato vacío    4              301.0    20214
# 122578     octubre        16.0    dato vacío   10               26.0   202210
# 7967    septiembre        95.0    dato vacío    9              105.0    20159
# 127278       junio         0.0    dato vacío    6               10.0    20236

# %%
# yyyy-mm-dd, yy-mm-dd, yymmdd, yyyy/dd/mm

# %%
# Agregamos la columna de fecha juntando el año y el mes
datos_long['fecha'] = pd.to_datetime(datos_long['anio'].astype(str) + datos_long['mes'].astype(str), format='%Y%m')
datos_long.sample(5)
# Out:
#         anio  clave_ent              entidad        tipo_de_delito  \
# 54187   2018         17              Morelos    Tráfico de menores
# 108626  2022          3  Baja California Sur     Evasión de presos
# 15593   2016          1       Aguascalientes  Hostigamiento sexual
# 136043  2023         28           Tamaulipas           Feminicidio
# 16752   2016          3  Baja California Sur  Violación equiparada
#
#         nombre_mes  frecuencia nueva_columna  mes  frecuencia_mas_10 anio_mes  \
# 54187        marzo         0.0    dato vacío    3               10.0    20183
# 108626   diciembre         0.0    dato vacío   12               10.0   202212
# 15593        julio         0.0    dato vacío    7               10.0    20167
# 136043  septiembre         1.0    dato vacío    9               11.0    20239
# 16752        abril         3.0    dato vacío    4               13.0    20164
#
#             fecha
# 54187  2018-03-01
# 108626 2022-12-01
# 15593  2016-07-01
# 136043 2023-09-01
# 16752  2016-04-01

# %%
# Eliminamos las columnas que ya no necesitamos
datos_long = datos_long.drop(columns=['nueva_columna'])
datos_long.sample(5)
# Out:
#         anio  clave_ent          entidad                      tipo_de_delito  \
# 57244   2018         24  San Luis Potosí                             Despojo
# 48902   2018          6           Colima                  Tráfico de menores
# 66546   2019         11       Guanajuato     Otros delitos contra la familia
# 158714  2025         11       Guanajuato    Otros delitos contra la sociedad
# 92458   2021          1   Aguascalientes  Otros delitos contra el patrimonio
#
#        nombre_mes  frecuencia  mes  frecuencia_mas_10 anio_mes      fecha
# 57244     febrero        31.0    2               41.0    20182 2018-02-01
# 48902   diciembre         0.0   12               10.0   201812 2018-12-01
# 66546       junio         0.0    6               10.0    20196 2019-06-01
# 158714  diciembre         0.0   12               10.0   202512 2025-12-01
# 92458     octubre        14.0   10               24.0   202110 2021-10-01

# %% [markdown]
# Veamos los homicidios en oaxaca de enero 2024 a la fecha

# %%
datos_long[
    (datos_long.tipo_de_delito == "Homicidio") &
    (datos_long.clave_ent == 20) &
    (datos_long.fecha >= '2024-01-01')
].sort_values('fecha')
# Out:
#         anio  clave_ent entidad tipo_de_delito  nombre_mes  frecuencia  mes  \
# 147579  2024         20  Oaxaca      Homicidio       enero       154.0    1
# 147580  2024         20  Oaxaca      Homicidio     febrero       166.0    2
# 147583  2024         20  Oaxaca      Homicidio       marzo       184.0    3
# 147576  2024         20  Oaxaca      Homicidio       abril       200.0    4
# 147584  2024         20  Oaxaca      Homicidio        mayo       223.0    5
# 147582  2024         20  Oaxaca      Homicidio       junio       195.0    6
# 147581  2024         20  Oaxaca      Homicidio       julio       201.0    7
# 147577  2024         20  Oaxaca      Homicidio      agosto       186.0    8
# 147587  2024         20  Oaxaca      Homicidio  septiembre       190.0    9
# 147586  2024         20  Oaxaca      Homicidio     octubre       185.0   10
# 147585  2024         20  Oaxaca      Homicidio   noviembre       168.0   11
# 147578  2024         20  Oaxaca      Homicidio   diciembre       151.0   12
# 162939  2025         20  Oaxaca      Homicidio       enero       170.0    1
# 162940  2025         20  Oaxaca      Homicidio     febrero       141.0    2
# 162943  2025         20  Oaxaca      Homicidio       marzo       193.0    3
# 162936  2025         20  Oaxaca      Homicidio       abril       185.0    4
# 162944  2025         20  Oaxaca      Homicidio        mayo       172.0    5
# 162942  2025         20  Oaxaca      Homicidio       junio       132.0    6
# 162941  2025         20  Oaxaca      Homicidio       julio       159.0    7
# 162937  2025         20  Oaxaca      Homicidio      agosto       106.0    8
# 162947  2025         20  Oaxaca      Homicidio  septiembre        96.0    9
# 162946  2025         20  Oaxaca      Homicidio     octubre        85.0   10
# 162945  2025         20  Oaxaca      Homicidio   noviembre         0.0   11
# 162938  2025         20  Oaxaca      Homicidio   diciembre         0.0   12
#
#         frecuencia_mas_10 anio_mes      fecha
# 147579              164.0    20241 2024-01-01
# 147580              176.0    20242 2024-02-01
# 147583              194.0    20243 2024-03-01
# 147576              210.0    20244 2024-04-01
# 147584              233.0    20245 2024-05-01
# 147582              205.0    20246 2024-06-01
# 147581              211.0    20247 2024-07-01
# 147577              196.0    20248 2024-08-01
# 147587              200.0    20249 2024-09-01
# 147586              195.0   202410 2024-10-01
# 147585              178.0   202411 2024-11-01
# 147578              161.0   202412 2024-12-01
# 162939              180.0    20251 2025-01-01
# 162940              151.0    20252 2025-02-01
# 162943              203.0    20253 2025-03-01
# 162936              195.0    20254 2025-04-01
# 162944              182.0    20255 2025-05-01
# 162942              142.0    20256 2025-06-01
# 162941              169.0    20257 2025-07-01
# 162937              116.0    20258 2025-08-01
# 162947              106.0    20259 2025-09-01
# 162946               95.0   202510 2025-10-01
# 162945               10.0   202511 2025-11-01
# 162938               10.0   202512 2025-12-01

# %%
datos_finales = datos_long[['anio', 'clave_ent', 'entidad', 'tipo_de_delito', 'nombre_mes', 'fecha', 'frecuencia']]
datos_finales.head(2)
# Out:
#    anio  clave_ent         entidad tipo_de_delito nombre_mes      fecha  \
# 0  2015          1  Aguascalientes         Aborto      abril 2015-04-01
# 1  2015          1  Aguascalientes         Aborto     agosto 2015-08-01
#
#    frecuencia
# 0         0.0
# 1         0.0

# %% [markdown]
# Ya que tenemos muestros datos bien estructurados, los podemos guardar en nuestra computadora. Los guardaremos con el nombre "delitos.csv"

# %%
datos_finales.to_csv('sample_data/delitos.csv', index=False)
